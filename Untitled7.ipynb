# %% [markdown]
# <a href="https://colab.research.google.com/github/adriano020/COMPARADORES-E-OPERADORES/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("8 e maior que 7:", 8>7)
print("8 e menor que 7:", 8<7)
print(8==7)
print(10>=10)
print(10<10)
print(10<=10)
# Out:
# 8 e maior que 7: True
# 8 e menor que 7: False
# False
# True
# False
# True

# %%
ATIVIDADE 01

# %%
idade1 = int(input('digite sua dade:'))
idade2 = int(input('digite sua idade:'))
print(idade1==idade2)
print(idade1!=idade2)
print(idade1>idade2)
print(idade1>=idade2)
print(idade1<idade2)
print(idade1<=idade2)
# Out:
# digite sua dade:25
# digite sua idade:30
# False
# True
# False
# False
# True
# True

# %%
idade = int(input('digite sua idade:'))
convite = input("tem convite? (sim/nao)")
resultado = (idade >=18) and (convite =="sim")
print(resultado)
# Out:
# digite sua idade:20
# tem convite? (sim/nao)sim
# True

# %%
usuario = (input('digite o usuario:'))
senha = (input('digite a senha'))
resultado = (usuario == "admin") and (senha == "1234")
print(resultado)
# Out:
# digite o usuario:admin
# digite a senha1234
# True

# %%
vip = input('voce e cliente vip? sim/não')
valor = float(input('digite o valor da compra:'))
resultado = (vip == "sim") or (valor >100)
print(resultado)
# Out:
# voce e cliente vip? sim/nãonao
# digite o valor da compra:99
# False

# %%
dia = input('digite o dia da semana:')
resultado = (dia == 'segunda' or dia == 'terca' or dia == 'quarta' or dia == 'quinta' or 'sexta')
print(resultado)
# Out:
# digite o dia da semana:terça
# sexta
